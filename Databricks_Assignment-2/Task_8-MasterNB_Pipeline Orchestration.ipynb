# %%
try:
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_1-RawData_to_Bronze", 600)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_2-Bronze_to_Silver", 600)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_3 - SCD2_Implementation", 600)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_4-Fact Table Creation",600)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_5-Silver_to_Gold",600)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_6-Data_Quality_Validation",300)
    dbutils.notebook.run("/Workspace/Users/kishelake12@gmail.com/Databricks-POC_Assig2/Databricks_Assignment-2/Task_7-Delta_Lake_Time_Travel_Rollback",300)

    print("Execution Successful! :)")

except Exception as e:
    print("Execution Failed! :(") 
    raise e
